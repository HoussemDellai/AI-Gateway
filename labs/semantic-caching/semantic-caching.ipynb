# %% [markdown]
# # APIM ❤️ OpenAI
#
# ## Semantic Caching lab
# ![flow](../../images/semantic-caching.gif)
#
# Playground to try the [semantic caching policy](https://learn.microsoft.com/en-us/azure/api-management/azure-openai-semantic-cache-lookup-policy).
#
# The azure-openai-semantic-cache-lookup policy conducts a cache lookup of responses on Azure OpenAI Chat Completion API and Completion API requests from a pre-configured external cache. It operates by comparing the vector proximity of the prompt to prior requests and using a specific similarity score threshold. Caching responses helps reduce bandwidth and processing demands on the backend Azure OpenAI API, thus reducing latency perceived by API consumers.
#
# [View policy configuration](policy.xml)
#
# ### Result
# ![result](result.png)
#
# ### TOC
# - [0️⃣ Initialize notebook variables](#0)
# - [1️⃣ Create the Azure Resource Group](#1)
# - [2️⃣ Create deployment using 🦾 Bicep](#2)
# - [3️⃣ Get the deployment outputs](#3)
# - [🧪 Make multiple calls using the Azure OpenAI Python SDK](#sdk)
# - [🔍 Analyze Semantic Caching performance](#plot)
# - [🗑️ Clean up resources](#clean)
#
# ### Prerequisites
# - [Python 3.8 or later version](https://www.python.org/) installed
# - [Pandas Library](https://pandas.pydata.org/) and matplotlib installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Azure CLI](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli) installed
# - [An Azure Subscription](https://azure.microsoft.com/en-us/free/) with Contributor permissions
# - [Access granted to Azure OpenAI](https://aka.ms/oai/access) or just enable the mock service
# - [Sign in to Azure with Azure CLI](https://learn.microsoft.com/en-us/cli/azure/authenticate-azure-cli-interactively)

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/en-us/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/en-us/azure/ai-services/openai/concepts/models)

# %%
import os
import json
import datetime
import requests

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"rg-lab-{deployment_name}" # change the name to match your naming style
resource_group_location = "westeurope"
apim_resource_name = "apim0013"
apim_resource_location = "westeurope"
apim_resource_sku = "Basicv2"
openai_resources = [ {"name": "openai13", "location": "swedencentral"} ] # list of OpenAI resources to deploy. Clear this list to use only the mock resources
openai_resources_sku = "S0"
openai_model_name = "gpt-35-turbo"
openai_model_version = "0613"
openai_deployment_name = "gpt-35-turbo"
openai_api_version = "2024-02-01"
openai_specification_url='https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/' + openai_api_version + '/inference.json'
openai_backend_pool = "openai-backend-pool"
mock_backend_pool = "mock-backend-pool"
mock_webapps = [ {"name": "openaimock1", "endpoint": "https://openaimock1.azurewebsites.net"}, {"name": "openaimock2", "endpoint": "https://openaimock2.azurewebsites.net"} ]

log_analytics_name = "workspace"
app_insights_name = 'insights'
embeddings_model_name = "text-embedding-ada-002"
embeddings_model_version = "2"
embeddings_deployment_name = "text-embedding-ada-002"
rediscache_name = "rediscache"

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Create the Azure Resource Group
# All resources deployed in this lab will be created in the specified resource group. Skip this step if you want to use an existing resource group.

# %%
resource_group_stdout = ! az group create --name {resource_group_name} --location {resource_group_location}
if resource_group_stdout.n.startswith("ERROR"):
    print(resource_group_stdout)
else:
    print("✅ Azure Resource Group ", resource_group_name, " created ⌚ ", datetime.datetime.now().time())
# Out:
# ✅ Azure Resource Group  rg-lab-semantic-caching  created ⌚  17:02:43.541533

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/en-us/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.

# %%
if len(openai_resources) > 0:
    backend_id = openai_backend_pool if len(openai_resources) > 1 else openai_resources[0].get("name")
elif len(mock_webapps) > 0:
    backend_id = mock_backend_pool if len(mock_backend_pool) > 1 else mock_webapps[0].get("name")

with open("policy.xml", 'r') as policy_xml_file:
    policy_template_xml = policy_xml_file.read()
    policy_xml = policy_template_xml.replace("{backend-id}", backend_id)
    policy_xml_file.close()
open("policy.xml", 'w').write(policy_xml)

bicep_parameters = {
  "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
  "contentVersion": "1.0.0.0",
  "parameters": {
    "mockWebApps": { "value": mock_webapps },
    "mockBackendPoolName": { "value": mock_backend_pool },
    "openAIBackendPoolName": { "value": openai_backend_pool },
    "openAIConfig": { "value": openai_resources },
    "openAIDeploymentName": { "value": openai_deployment_name },
    "openAISku": { "value": openai_resources_sku },
    "openAIModelName": { "value": openai_model_name },
    "openAIModelVersion": { "value": openai_model_version },
    "openAIAPISpecURL": { "value": openai_specification_url },
    "apimResourceName": { "value": apim_resource_name},
    "apimResourceLocation": { "value": apim_resource_location},
    "apimSku": { "value": apim_resource_sku},
    "logAnalyticsName": { "value": log_analytics_name },
    "applicationInsightsName": { "value": app_insights_name },
    "embeddingsModelName": { "value": embeddings_model_name },
    "embeddingsModelVersion": { "value": embeddings_model_version },
    "embeddingsDeploymentName": { "value": embeddings_deployment_name },
    "redisCacheName": { "value": rediscache_name }
  }
}
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

! az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file "main.bicep" --parameters "params.json"

open("policy.xml", 'w').write(policy_template_xml)
# Out:
# {
#   "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Resources/deployments/semantic-caching",
#   "location": null,
#   "name": "semantic-caching",
#   "properties": {
#     "correlationId": "41167e8a-e564-429a-88ef-d35b2701cfd7",
#     "debugSetting": null,
#     "dependencies": [
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/caches/Default",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/Default",
#         "resourceType": "Microsoft.ApiManagement/service/caches"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/backends/embeddings-backend",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/embeddings-backend",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/openai",
#         "resourceType": "Microsoft.ApiManagement/service/apis"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai/policies/policy",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/openai/policy",
#         "resourceType": "Microsoft.ApiManagement/service/apis/policies"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/subscriptions/openai-subscription",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/openai-subscription",
#         "resourceType": "Microsoft.ApiManagement/service/subscriptions"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.OperationalInsights/workspaces/workspace-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "workspace-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.OperationalInsights/workspaces"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/components/insights-gwuzbjgkaqkuk",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "insights-gwuzbjgkaqkuk",
#         "resourceType": "Microsoft.Insights/components"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/components/insights-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "insights-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.Insights/components"
#           },
#           {
#             "apiVersion": "2020-02-02",
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/components/insights-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "insights-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/loggers/apim-logger",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/apim-logger",
#         "resourceType": "Microsoft.ApiManagement/service/loggers"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk/openai",
#             "resourceType": "Microsoft.ApiManagement/service/apis"
#           },
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/loggers/apim-logger",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk/apim-logger",
#             "resourceType": "Microsoft.ApiManagement/service/loggers"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/openai/applicationinsights",
#         "resourceType": "Microsoft.ApiManagement/service/apis/diagnostics"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/components/insights-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "insights-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.Insights/components"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/workbooks/2e0b9847-dd65-53e0-8547-7ca95aef8849",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "2e0b9847-dd65-53e0-8547-7ca95aef8849",
#         "resourceType": "Microsoft.Insights/workbooks"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk/deployments/gpt-35-turbo",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "openai13-gwuzbjgkaqkuk/gpt-35-turbo",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk/deployments/text-embedding-ada-002-rediscache",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "openai13-gwuzbjgkaqkuk/text-embedding-ada-002-rediscache",
#         "resourceType": "Microsoft.CognitiveServices/accounts/deployments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2023-05-01-preview",
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk/providers/Microsoft.Authorization/roleAssignments/cdeb4600-8d8b-5e17-a28c-af3e34880452",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "cdeb4600-8d8b-5e17-a28c-af3e34880452",
#         "resourceType": "Microsoft.Authorization/roleAssignments"
#       },
#       {
#         "dependsOn": [
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "apim0013-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.ApiManagement/service"
#           },
#           {
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           },
#           {
#             "apiVersion": "2021-10-01",
#             "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#             "resourceGroup": "rg-lab-semantic-caching",
#             "resourceName": "openai13-gwuzbjgkaqkuk",
#             "resourceType": "Microsoft.CognitiveServices/accounts"
#           }
#         ],
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/backends/openai13",
#         "resourceGroup": "rg-lab-semantic-caching",
#         "resourceName": "apim0013-gwuzbjgkaqkuk/openai13",
#         "resourceType": "Microsoft.ApiManagement/service/backends"
#       }
#     ],
#     "duration": "PT39.5926872S",
#     "error": null,
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai/diagnostics/applicationinsights",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/apis/openai/policies/policy",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/backends/embeddings-backend",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/backends/openai13",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/caches/Default",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/loggers/apim-logger",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk/subscriptions/openai-subscription",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk/deployments/gpt-35-turbo",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk/deployments/text-embedding-ada-002-rediscache",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.CognitiveServices/accounts/openai13-gwuzbjgkaqkuk/providers/Microsoft.Authorization/roleAssignments/cdeb4600-8d8b-5e17-a28c-af3e34880452",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/components/insights-gwuzbjgkaqkuk",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.Insights/workbooks/2e0b9847-dd65-53e0-8547-7ca95aef8849",
#         "resourceGroup": "rg-lab-semantic-caching"
#       },
#       {
#         "id": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.OperationalInsights/workspaces/workspace-gwuzbjgkaqkuk",
#         "resourceGroup": "rg-lab-semantic-caching"
#       }
#     ],
#     "outputs": {
#       "apimResourceGatewayURL": {
#         "type": "String",
#         "value": "https://apim0013-gwuzbjgkaqkuk.azure-api.net"
#       },
#       "apimServiceId": {
#         "type": "String",
#         "value": "/subscriptions/dcef7009-6b94-4382-afdc-17eb160d709a/resourceGroups/rg-lab-semantic-caching/providers/Microsoft.ApiManagement/service/apim0013-gwuzbjgkaqkuk"
#       },
#       "apimSubscriptionKey": {
#         "type": "String",
#         "value": "585ae095e41f446a93dccd43dd5d2033"
#       },
#       "applicationInsightsAppId": {
#         "type": "String",
#         "value": "fbd83ba9-c160-4541-9981-76c8f736c73e"
#       },
#       "logAnalyticsWorkspaceId": {
#         "type": "String",
#         "value": "3306c5b5-dd79-4816-b37a-6f94aa59daef"
#       }
#     },
#     "parameters": {
#       "apiDiagnosticsLogBytes": {
#         "type": "Int",
#         "value": 8192
#       },
#       "apimLoggerDescription": {
#         "type": "String",
#         "value": "APIM Logger for OpenAI API"
#       },
#       "apimLoggerName": {
#         "type": "String",
#         "value": "apim-logger"
#       },
#       "apimPublisherEmail": {
#         "type": "String",
#         "value": "noreply@microsoft.com"
#       },
#       "apimPublisherName": {
#         "type": "String",
#         "value": "Microsoft"
#       },
#       "apimResourceLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "apimResourceName": {
#         "type": "String",
#         "value": "apim0013"
#       },
#       "apimSku": {
#         "type": "String",
#         "value": "Basicv2"
#       },
#       "apimSkuCount": {
#         "type": "Int",
#         "value": 1
#       },
#       "applicationInsightsLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "applicationInsightsName": {
#         "type": "String",
#         "value": "insights"
#       },
#       "embeddingsDeploymentName": {
#         "type": "String",
#         "value": "text-embedding-ada-002"
#       },
#       "embeddingsModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "embeddingsModelName": {
#         "type": "String",
#         "value": "text-embedding-ada-002"
#       },
#       "embeddingsModelVersion": {
#         "type": "String",
#         "value": "2"
#       },
#       "logAnalyticsLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "logAnalyticsName": {
#         "type": "String",
#         "value": "workspace"
#       },
#       "mockBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI Mocking endpoints"
#       },
#       "mockBackendPoolName": {
#         "type": "String",
#         "value": "mock-backend-pool"
#       },
#       "mockWebApps": {
#         "type": "Array",
#         "value": [
#           {
#             "endpoint": "https://openaimock1.azurewebsites.net",
#             "name": "openaimock1"
#           },
#           {
#             "endpoint": "https://openaimock2.azurewebsites.net",
#             "name": "openaimock2"
#           }
#         ]
#       },
#       "openAIAPIDescription": {
#         "type": "String",
#         "value": "Azure OpenAI API inferencing API"
#       },
#       "openAIAPIDisplayName": {
#         "type": "String",
#         "value": "OpenAI"
#       },
#       "openAIAPIName": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPIPath": {
#         "type": "String",
#         "value": "openai"
#       },
#       "openAIAPISpecURL": {
#         "type": "String",
#         "value": "https://raw.githubusercontent.com/Azure/azure-rest-api-specs/main/specification/cognitiveservices/data-plane/AzureOpenAI/inference/stable/2024-02-01/inference.json"
#       },
#       "openAIBackendPoolDescription": {
#         "type": "String",
#         "value": "Load balancer for multiple OpenAI endpoints"
#       },
#       "openAIBackendPoolName": {
#         "type": "String",
#         "value": "openai-backend-pool"
#       },
#       "openAIConfig": {
#         "type": "Array",
#         "value": [
#           {
#             "location": "swedencentral",
#             "name": "openai13"
#           }
#         ]
#       },
#       "openAIDeploymentName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelCapacity": {
#         "type": "Int",
#         "value": 20
#       },
#       "openAIModelName": {
#         "type": "String",
#         "value": "gpt-35-turbo"
#       },
#       "openAIModelVersion": {
#         "type": "String",
#         "value": "0613"
#       },
#       "openAISku": {
#         "type": "String",
#         "value": "S0"
#       },
#       "openAISubscriptionDescription": {
#         "type": "String",
#         "value": "OpenAI Subscription"
#       },
#       "openAISubscriptionName": {
#         "type": "String",
#         "value": "openai-subscription"
#       },
#       "redisCacheCapacity": {
#         "type": "Int",
#         "value": 2
#       },
#       "redisCacheLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "redisCacheName": {
#         "type": "String",
#         "value": "rediscache"
#       },
#       "redisCacheSKU": {
#         "type": "String",
#         "value": "Standard_C_1"
#       },
#       "redisEvictionPolicy": {
#         "type": "String",
#         "value": "NoEviction"
#       },
#       "redisPort": {
#         "type": "Int",
#         "value": 10000
#       },
#       "workbookDisplayName": {
#         "type": "String",
#         "value": "OpenAI Usage Analysis"
#       },
#       "workbookLocation": {
#         "type": "String",
#         "value": "westeurope"
#       },
#       "workbookName": {
#         "type": "String",
#         "value": "OpenAIUsageAnalysis"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.ApiManagement",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "service",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/caches",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/backends",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/policies",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/subscriptions",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/loggers",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "service/apis/diagnostics",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.OperationalInsights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workspaces",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Insights",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "components",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "westeurope"
#             ],
#             "properties": null,
#             "resourceType": "workbooks",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.CognitiveServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "swedencentral"
#             ],
#             "properties": null,
#             "resourceType": "accounts",
#             "zoneMappings": null
#           },
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "accounts/deployments",
#             "zoneMappings": null
#           }
#         ]
#       },
#       {
#         "id": null,
#         "namespace": "Microsoft.Authorization",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               null
#             ],
#             "properties": null,
#             "resourceType": "roleAssignments",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "7555476378337645756",
#     "templateLink": null,
#     "timestamp": "2025-01-05T16:10:17.133629+00:00",
#     "validatedResources": null
#   },
#   "resourceGroup": "rg-lab-semantic-caching",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }
# WARNING: d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(139,7) : Warning no-unused-params: Parameter "redisCacheLocation" is declared but never used. [https://aka.ms/bicep/linter/no-unused-params]
#
# d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(145,7) : Warning no-unused-params: Parameter "redisCacheSKU" is declared but never used. [https://aka.ms/bicep/linter/no-unused-params]
#
# d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(148,7) : Warning no-unused-params: Parameter "redisCacheCapacity" is declared but never used. [https://aka.ms/bicep/linter/no-unused-params]
#
# d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(151,7) : Warning no-unused-params: Parameter "redisEvictionPolicy" is declared but never used. [https://aka.ms/bicep/linter/no-unused-params]
#
# d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(154,7) : Warning no-unused-params: Parameter "redisPort" is declared but never used. [https://aka.ms/bicep/linter/no-unused-params]
#
# d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(379,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP035]
#
# d:\projects\AI-Gateway\labs\semantic-caching\main.bicep(396,3) : Warning BCP035: The specified "object" declaration is missing the following required properties: "protocol", "url". If this is a resource type definition inaccuracy, report it using https://aka.ms/bicep-type-issues. [https://aka.ms/bicep/core-diagnostics#BCP035]
# 915

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs
#
# We are now at the stage where we only need to retrieve the gateway URL and the subscription before we are ready for testing.

# %%
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimSubscriptionKey.value -o tsv
apim_subscription_key = deployment_stdout.n
deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.apimResourceGatewayURL.value -o tsv
apim_resource_gateway_url = deployment_stdout.n
print("👉🏻 API Gateway URL: ", apim_resource_gateway_url)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.logAnalyticsWorkspaceId.value -o tsv
workspace_id = deployment_stdout.n
print("👉🏻 Workspace ID: ", workspace_id)

deployment_stdout = ! az deployment group show --name {deployment_name} -g {resource_group_name} --query properties.outputs.applicationInsightsAppId.value -o tsv
app_id = deployment_stdout.n
print("👉🏻 App ID: ", app_id)
# Out:
# 👉🏻 API Gateway URL:
# 👉🏻 Workspace ID:
# 👉🏻 App ID:

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Make multiple calls using the Azure OpenAI Python SDK
#
# The code below contains a list of questions that will be randomly selected and sent as prompts to the OpenAI API

# %%
from openai import AzureOpenAI
import time, random

runs = 10
questions = ["Can you tell me the time, please?", 
             "Would you be so kind as to inform me of the current time, if possible?", 
             "Could you please inform me of the current time?", 
             "Could you kindly inform me of the current time, please?"]
api_runs = []  # Response Times for each run
for i in range(runs):
    random_question = random.choice(questions)
    messages=[
        {"role": "system", "content": "You are a sarcastic unhelpful assistant."},
        {"role": "user", "content": random_question}
    ]
    client = AzureOpenAI(azure_endpoint=apim_resource_gateway_url, api_key=apim_subscription_key, api_version=openai_api_version)
    start_time = time.time()
    response = client.chat.completions.create(model=openai_model_name, messages=messages)
    response_time = time.time() - start_time
    print("▶️ Run: ", i+1, f"duration: {response_time:.2f} seconds")
    print("💬 ", random_question, response.choices[0].message.content)
    api_runs.append(response_time)

# %% [markdown]
# <a id='plot'></a>
# ### 🔍 Analyze Semantic Caching performance

# %%
# plot the results
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

mpl.rcParams['figure.figsize'] = [15, 5]
df = pd.DataFrame(api_runs, columns=['Response Time'])
df['Run'] = range(1, len(df) + 1)
df.plot(kind='bar', x='Run', y='Response Time', legend=False)
plt.title('Semantic Caching Performance')
plt.xlabel('Runs')
plt.ylabel('Response Time (s)')
plt.xticks(df['Run'], rotation=0)  # Set x-axis ticks to be the run numbers

average = df['Response Time'].mean()
plt.axhline(y=average, color='r', linestyle='--', label=f'Average: {average:.2f}')
plt.legend()

plt.show()

# %% [markdown]
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
